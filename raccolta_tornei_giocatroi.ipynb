experiment":-1458757693,"minFlavor":"domadaptermi-1.17.1.340.js100"}; minUnifiedSessionToken10=%7B%22sessionId%22%3A%2206e733138f-cc3d03dcdb-4ade831696-18c9724b12-b53987a23c%22%2C%22uid%22%3A%22f41bebc88e-f74aab2ef6-1546943d67-e71e6f1e6d-d4823be30c%22%2C%22__sidts__%22%3A1767604248056%2C%22__uidts__%22%3A1767604248056%7D; __gads=ID=4cac3b716646e0a5:T=1766137003:RT=1767611906:S=ALNI_MZ4d7xGcu-RbsGXF0flML-O6zEd5w; shell#lang=en; cebs=1; _ce.clock_data=-488%2C137.194.252.217%2C1%2C89db729cfcdc129111f017b0e7ac324a%2CChrome%2CFR; cf_clearance=qBiYmOgkFe_0s0WE98HuK2A9H0dRlbF1FYrgYs_wXpI-1767952073-1.2.1.1-T0MFkwUZ3axAVdSCvXBXTRZqvyNcE0uXB2RCGSyO8l.3Cy41FHnA98rA0UgDh_9akg8H0M1CsWZTu_QgEw7TLDIMR39CxJe3WCBlkPZdK_plF4Mol.mTqPiyUEEN_RP87pY.aKVUk4O3cvOSuf4Q4YtPiRJWIuWdrGODgQLreyPsMjJrXtqpZKUzv5uGKl8.bAGPk1zjJ5mgriLVDIRSB7BZ9CudgJ6EMx_TV7zFNP8; __eoi=ID=31dbfb1d854a8e18:T=1765205408:RT=1767952073:S=AA-AfjZXftV4Ak3_WWnoZSktaV6O; _ce.s=v~24ee0f35aab71fdf2d8e76355e6acfb4b9d6b732~lcw~1767952073271~vir~returning~lva~1767948087964~vpv~6~v11ls~449264e0-ed40-11f0-9f84-c97a3f8534f3~v11.cs~356004~v11.s~449264e0-ed40-11f0-9f84-c97a3f8534f3~v11.vs~24ee0f35aab71fdf2d8e76355e6acfb4b9d6b732~v11.fsvd~eyJ1cmwiOiJhdHB0b3VyLmNvbS9lbi9wbGF5ZXJzL3RyaXN0YW4tc2Nob29sa2F0ZS8qL3BsYXllci1hY3Rpdml0eSIsInJlZiI6Imh0dHBzOi8vd3d3LmF0cHRvdXIuY29tL2VuL3BsYXllcnMvdHJpc3Rhbi1zY2hvb2xrYXRlL3MwbjAvb3ZlcnZpZXciLCJ1dG0iOltdfQ%3D%3D~v11.sla~1767952073265~v11.wss~1767952073266~v11.ss~1767952073270~lcw~1767952073275; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Jan+09+2026+10%3A49%3A03+GMT%2B0100+(Ora+standard+dell%E2%80%99Europa+centrale)&version=202502.1.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=4e6bd1b2-e205-4b86-80f6-05ea2f4a2899&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0004%3A0%2CC0003%3A0&intType=2&geolocation=FR%3BIDF&AwaitingReconsent=false; cebsp_=21; __cf_bm=kRIArIT4N2IT.q1dkESzMUWfeDHJWBZFkkV4Lae1G3A-1767952722-1.0.1.1-10dE4Npm3EYLcU_VcYLgPl1eFFfvxwotCEI6O.rAQJ6LtNE9gM4oE2gDSzyuXghL.K88jdYWeyNgFlIAa267oG6Lnp6HDe9WgzQJrtsz_NM',
}

params = {
    'v': '1',
}

# %%
from bs4 import BeautifulSoup as bs
import json
import requests
import pandas as pd

# %%
#writing csv from dataframe and saving it
def write_csv_from_df(df, filename):
    df.to_csv(filename, index=False)

# %%
file_name_denti = "atp_senza_ripetizioni.csv"
file_senza_denti = open(file_name_denti, "r", encoding="utf-8")
lista_codici_players=[]

for line in file_senza_denti:
    if line.strip() != "" and not line.startswith("Player Id"):
        lista_codici_players.append(line.strip().split(",")[0])
print(lista_codici_players[:250])
lista_codici_players = lista_codici_players[:250]
print(len(lista_codici_players))
# Out:
# ['sg56', 'da86', 'j09x', 'mj71', 'v821', 's0k7', 'rc91', 'mc10', 'c0h0', 'h996', 'hg94', 'n0ae', 'su87', 'c0bc', 'me82', 'o0a2', 'g858', 'u134', 'bk92', 'rh24', 'r772', 'pg94', 'v717', 'wb25', 'm0ht', 'm0hu', 'o522', 'i306', 'mw54', 's0nv', 'r0eb', 'd0co', 'c0ak', 'e811', 's0n0', 'd864', 'b0cd', 'sx91', 's0aq', 'm0oq', 'r0a7', 'l0cx', 'gb53', 'm0qi', 'ss25', 'j620', 'dc48', 'h0cx', 'i186', 'm0gz', 'r0fp', 'sm37', 'l0gh', 'n897', 'fc49', 'ta12', 'a887', 'dc76', 'm0ni', 'w09e', 'li03', 'j380', 'ea13', 'p0hw', 'lf29', 'c977', 'n409', 'z09z', 'm0ac', 'o482', 'p0e9', 'k0e6', 'mk26', 'k0a3', 'k0hc', 'b0bi', 'pc11', 's0ak', 't09x', 'a0cj', 'me89', 'bk19', 'n679', 'ke17', 'wb19', 'j0az', 'cd85', 'ta46', 'hb48', 'v812', 'bk40', 'pj74', 'mw76', 'h0du', 'bi81', 'b0ej', 's0ti', 'sm09', 'ki95', 'd0dt', 'hd68', 'f0dm', 'su55', 'r0go', 'bd06', 'w0bh', 'm0nb', 'dg80', 'd0dp', 'v0b2', 'h09n', 'm0bn', 'n732', 'pf39', 'lc11', 'ca99', 'kd35', 'q02l', 'r975', 'g0dh', 'pg20', 'v0di', 'f0f2', 'hf80', 'c0bh
# ...

# %%
#response = requests.get(f"https://www.atptour.com/en/-/www/activity/sgl/v0di", params=params, cookies=cookies, headers=headers)    
#js = response.json()
#print(js)

# %%
#for i in js["Activity"]:
 #   for j in i["Tournaments"]:
  #      print(j["Location"]["EventLocation"])

# %%
from datetime import datetime
url_incomplete = f"https://www.atptour.com/en/-/www/activity/sgl/"
anni = [2022,2023,2024,2025]
columns=[
                "Year","EventId","PlayerCode","Date","EventName","EventType","EventCountry",
                "PlayerRank","PointsGained","PrizeUsd","SglDrawSize","Surface","TotPrizeMoney"
            ]

df_2022 = pd.DataFrame(columns=columns)
df_2023 = pd.DataFrame(columns=columns)
df_2024 = pd.DataFrame(columns=columns)
df_2025 = pd.DataFrame(columns=columns)
i=0
for c in lista_codici_players:
    i+=1
    print(f"Processing player {i}/{len(lista_codici_players)}: {c}")
    #per ongi giocatore estraggo tutti i tornei, uno per anno    
    url = f"https://www.atptour.com/en/-/www/activity/sgl/{c}/"
    print(url)
    response = requests.get(url, params=params, cookies=cookies, headers=headers)
    
    js = response.json()
    
    for yearly_activity in js["Activity"]:
        if yearly_activity["EventYear"] in anni:
            yearly_tournaments = yearly_activity["Tournaments"]
            year = yearly_activity["EventYear"]
            
            #creo un dataframe per ogni anno
            #df_filename = f"PROVA_data_{year}.csv"
            
            
            #per ogni anno ora prendo ogni singolo torneo, TUTTI I TIPI
            for t in yearly_tournaments:
                if t["Display"]==True: #there are some "strange" tournaments with Display=False
    
                    player_code = c
                    event_id = t["EventId"]
                    #data di fine torneo
                    event_date = datetime.fromisoformat(t["EventDate"]).date()
                    event_name = t["EventName"]
                    event_type = t["EventType"]
                    event_location = t["Location"]["EventLocation"]
                    player_rank = t["PlayerRank"]
                    points_gained = t["Points"]
                    player_prize = t["PrizeUsd"]
                    event_draw_size = t["SglDrawSize"]
                    event_surface = t["Surface"]
                    event_tot_prize_money = t["TotPrizeMoney"]
                    
                    row = {
                        "EventId": event_id,
                        "Date": event_date,
                        "EventName": event_name,
                        "EventType": event_type,
                        "EventCountry": event_location,
                        "PlayerRank": player_rank,
                        "PointsGained": points_gained,
                        "PrizeUsd": player_prize,
                        "SglDrawSize": event_draw_size,
                        "Surface": event_surface,
                        "TotPrizeMoney": event_tot_prize_money,
                        "Year": year,
                        "PlayerCode": player_code}
                    
                    if year == 2022:
                        df_2022.loc[len(df_2022)]=row
                    elif year == 2023:
                        df_2023.loc[len(df_2023)]=row
                    elif year == 2024:
                        df_2024.loc[len(df_2024)]=row
                    elif year == 2025:
                        df_2025.loc[len(df_2025)]=row
                        
                    #yearly_df = yearly_df.loc[len(yearly_df)]=row
                                    
                    # if i==10:
                    #     break
write_csv_from_df(df_2022, "df_2022.csv")
print(f"Saved file: {df_2022}")
write_csv_from_df(df_2023, "df_2023.csv")
print(f"Saved file: {df_2023}")
write_csv_from_df(df_2024, "df_2024.csv")
print(f"Saved file: {df_2024}")
write_csv_from_df(df_2025, "df_2025.csv")
print(f"Saved file: {df_2025}")
# Out:
# Processing player 1/235: sg56
# https://www.atptour.com/en/-/www/activity/sgl/sg56/
# Processing player 2/235: da86
# https://www.atptour.com/en/-/www/activity/sgl/da86/
# Processing player 3/235: j09x
# https://www.atptour.com/en/-/www/activity/sgl/j09x/
# Processing player 4/235: mj71
# https://www.atptour.com/en/-/www/activity/sgl/mj71/
# Processing player 5/235: v821
# https://www.atptour.com/en/-/www/activity/sgl/v821/
# Processing player 6/235: s0k7
# https://www.atptour.com/en/-/www/activity/sgl/s0k7/
# Processing player 7/235: rc91
# https://www.atptour.com/en/-/www/activity/sgl/rc91/
# Processing player 8/235: mc10
# https://www.atptour.com/en/-/www/activity/sgl/mc10/
# Processing player 9/235: c0h0
# https://www.atptour.com/en/-/www/activity/sgl/c0h0/
# Processing player 10/235: h996
# https://www.atptour.com/en/-/www/activity/sgl/h996/
# Processing player 11/235: hg94
# https://www.atptour.com/en/-/www/activity/sgl/hg94/
# Processing player 12/235: n0ae
# ...

# %%
df_2024
# Out:
#       Year EventId PlayerCode  Date               EventName EventType  \
# 0     2024    2829       sg56   NaN                  Temuco        CH
# 1     2024    4882       sg56   NaN           M25 Sao Paulo        FU
# 2     2024     392       sg56   NaN             M25 Lajeado        FU
# 3     2024    2895       sg56   NaN                Curitiba        CH
# 4     2024    6307       sg56   NaN                Campinas        CH
# ...    ...     ...        ...   ...                     ...       ...
# 5945  2024    4676       n0db   NaN            M15 Prijedor        FU
# 5946  2024    4664       n0db   NaN               M15 Doboj        FU
# 5947  2024    4648       n0db   NaN  M15 Kursumlijska Banja        FU
# 5948  2024    2827       n0db   NaN          Szekesfehervar        CH
# 5949  2024    4514       n0db   NaN           G1 BUL vs BIH        DC
#
#               EventCountry  PlayerRank  PointsGained  PrizeUsd  SglDrawSize  \
# ...
